# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('../../data/jobs.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85470 entries, 0 to 85469
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job_title       85463 non-null  object
#  1   job_type        85470 non-null  object
#  2   position_level  85470 non-null  object
#  3   city            85438 non-null  object
#  4   experience      85470 non-null  object
#  5   skills          74176 non-null  object
#  6   job_fields      77845 non-null  object
#  7   salary          85470 non-null  object
#  8   salary_min      85470 non-null  float64
#  9   salary_max      85470 non-null  float64
#  10  unit            85470 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 7.2+ MB

# %%
print(df.head())
# Out:
#                    job_title              job_type          position_level  \
# 0    trưởng phòng kinh doanh  nhân viên chính thức  trưởng nhóm , giám sát
# 1  nhân viên qc ngành cơ khí  nhân viên chính thức               nhân viên
# 2      trưởng phòng đấu thầu  nhân viên chính thức  trưởng nhóm , giám sát
# 3      home textile designer  nhân viên chính thức               nhân viên
# 4       nhân viên kinh doanh  nhân viên chính thức               nhân viên
#
#           city     experience  \
# 0  hồ chí minh  lên đến 1 năm
# 1  hồ chí minh     trên 1 năm
# 2  hồ chí minh      5 - 7 năm
# 3     hưng yên     5 - 15 năm
# 4  hồ chí minh     trên 1 năm
#
#                                               skills  \
# 0                                                NaN
# 1  production planning staff, chuyên viên iso, th...
# 2  trưởng phòng xây dựng, trưởng phòng đấu thầu, ...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
print(df.loc[df["skills"].notnull(), "skills"].head().to_list())
# Out:
# ['production planning staff, chuyên viên iso, thẩm tra đánh giá, nhân viên iso, nhân viên chất lượng, giám sát chất lượng, nhân viên qc ngành cơ khí, nhân viên quản lý chất lượng, qc staff', 'trưởng phòng xây dựng, trưởng phòng đấu thầu, dầu khí, trưởng phòng dầu khí, đấu thầu', 'sales director, giám đốc kinh doanh khu vực kem dẻo thổ nhĩ kỳ khu vực: khánh hòa phú yên bình định, giám đốc kinh doanh, area sales manager, giám đốc kinh doanh vùng, regional sales manager, sales manager', 'bất động sản, chuyên viên kinh doanh, bđs, real estate, môi giới, nhân viên kinh doanh bất động sản, nhân viên kinh doanh, real estate salesperson, chuyên viên kinh doanh bất động sản', 'kỹ thuật viên ie tiếng trung']

# %%
df[df["job_fields"].str.contains("Công nghệ", case=False, na=False)]
# Out:
#                                        job_title                job_type  \
# 65                                     head chef    nhân viên chính thức
# 81     kỹ thuật viên xét nghiệm sinh học phân tử    nhân viên chính thức
# 188           chuyên viên sản phẩm thiết bị y tế    nhân viên chính thức
# 265                  trình dược viên otc bảo lộc    nhân viên chính thức
# 306                       nhân viên vận hành máy    nhân viên chính thức
# ...                                          ...                     ...
# 41367       nhân viên mua hàng nhận việc sau tết  toàn thời gian cố định
# 41635            giám sát kinh doanh kênh gt hcm  toàn thời gian cố định
# 42139                                         qc  toàn thời gian cố định
# 42225       nhân viên mua hàng nhận việc sau tết  toàn thời gian cố định
# 42493            giám sát kinh doanh kênh gt hcm  toàn thời gian cố định
#
#                position_level         city     experience  \
# ...

# %%
job_fields = df[["job_fields"]]
job_fields['job_fields'] = job_fields["job_fields"].str.split(',')
job_fields = job_fields.explode('job_fields')
job_fields['job_fields'] = job_fields['job_fields'].str.strip()
unique_job = (job_fields['job_fields'].value_counts())

unique_job.to_csv('../../data/unique_job_fields.csv', index=True)
# Out:
# C:\Users\AN\AppData\Local\Temp\ipykernel_17900\3794242945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_fields['job_fields'] = job_fields["job_fields"].str.split(',')
